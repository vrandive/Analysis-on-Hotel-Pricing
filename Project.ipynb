# %%
import bs4
from bs4 import BeautifulSoup
import requests
import sqlite3

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
k = 0
rows = []
cols = []

#Create a new SQLite database
conn = sqlite3.connect('Hotel.db')

#Create a new table in the database to store the data
c = conn.cursor()
c.execute('''
        CREATE TABLE IF NOT EXISTS Hotel
        (
        Name char(100),
        Rating varchar(100),
        Performances varchar(100),
        Reviews varchar(100),
        Comfort varchar(100),
        Distances varchar(100),
        Location varchar(100),
        Price varchar(100),
        Discription varchar(100)
        )

''')
    
#Insert the data into the database
url = "https://www.booking.com/searchresults.en-us.html?label=gen173nr-1FCAEoggI46AdIM1gEaJgCiAEBmAExuAEHyAEN2AEB6AEB-AECiAIBqAIDuAKwscuiBsACAdICJDdiYmZjZDY0LTc3OTktNDA5Yi1iMTdmLWJlM2NlZTRkZGY0MdgCBeACAQ&aid=304142&ss=Los+Angeles&ssne=Los+Angeles&ssne_untouched=Los+Angeles&lang=en-us&sb=1&src_elem=sb&src=searchresults&dest_id=20014181&dest_type=city&checkin=2023-12-22&checkout=2024-01-05&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset=0"
response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.content, 'html.parser')

dataFrame = {
    'name' : ''
    'ratings' : ''
    'performance' : ''
    'reviews' : ''
    'comfort' : ''
    'distance' : ''
    'location' : ''
    'price' : ''
    'discription' : ''

}

name = ''
ratings= ''
performance = ''
reviews = ''
comfort = ''
distance = ''
location = ''
price = ''
discription = ''

print(len(soup.select('.fbd1d3018c')))
for i in soup.select('.a826ba81c4'):
    try:
        #name = i.select('.fcab3ed991')[0].get_text()
        ratings = i.select('.b5cd09854e')[0].get_text()
        performance = i.select('.f0d4d6a2f5')[0].get_text()
        reviews = i.select('.c90c0a70d3')[0].get_text()
        comfort = i.select('.f9afbb0024')[0].get_text()
        distance = i.select('span[aria-expanded="false"][data-testid="distance"]')[0].get_text()
        location = i.select('.b4273d69aa')[0].get_text()
        price = i.select('.fbd1d3018c')[0].get_text()
        discription = i.select('.df597226dd')[0].get_text()
        rows.append(i.select('.fcab3ed991')[0].get_text())
        cols.append(i.select('.f0d4d6a2f5')[0].get_text())
        
        #print('\n --------------------\n ')
    except Exception as e:
        print('')
print(rows)
print(cols)
#Commit the changes to the database and close the connection
conn.commit()
conn.close()
# Out:
# 27
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['Central Los Angeles Hollywood apartments', 'Hollywood Homes minutes to everything SPACIOUS AND FREE PARKING', 'Hollywood Historic Hotel', 'Modern Apartment Rentals', 'citizenM Los Angeles Downtown', 'The Metric - Los Angeles Downtown', 'AC Hotel by Marriott Los Angeles South Bay', "GORGEOUS Hollywood living los Angeles's best location", 'FORMAT STAYS Cozy Loft in Arts District DTLA', 'Quaint 1BD/1BA Bungalow- Venice Beach']
# ['Exceptional ', 'Excellent ', 'Very Good ', 'Very Good ', 'Excellent ', 'Wonderful ', 'Excellent ', 'Excellent ', 'Wonderful ', 'Wonderful ']

# %%
for j in range(1):
    #url = f"https://www.booking.com/searchresults.en-us.html?label=gen173nr-1FCAEoggI46AdIM1gEaJgCiAEBmAExuAEHyAEN2AEB6AEB-AECiAIBqAIDuAKwscuiBsACAdICJDdiYmZjZDY0LTc3OTktNDA5Yi1iMTdmLWJlM2NlZTRkZGY0MdgCBeACAQ&aid=304142&ss=Los+Angeles&ssne=Los+Angeles&ssne_untouched=Los+Angeles&lang=en-us&sb=1&src_elem=sb&src=searchresults&dest_id=20014181&dest_type=city&checkin=2023-12-22&checkout=2024-01-05&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset={k}"
    response = requests.get(url, headers = headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    k+=25
    for i in soup.select('.a826ba81c4'):
        #str1 = row.select('.fcab3ed991')[0].get_text()
        #str2 = row.select('.b5cd09854e')[0].get_text()
        #str3 = row.select('.f0d4d6a2f5')[0].get_text()
        #str4 = row.select('.c90c0a70d3')[0].get_text()
        #str5 = row.select('.f9afbb0024')[0].get_text()
        #str6 = row.select('span[aria-expanded="false"][data-testid="distance"]')[0].get_text()
        #str7 = row.select('.b4273d69aa')[0].get_text()
        #str8 = row.select('.fbd1d3018c')[0].get_text()
        #str9 = row.select('.df597226dd')[0].get_text()
        print(i.select('.fcab3ed991')[0].get_text())
        #c.executemany('INSERT INTO Hotel (Name, Rating, Performances, Reviews, Comfort, Distances, Location, Price, Discription) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)',row[str1],row[str2],row[str3],row[str4],row[str5],row[str6],row[str7],row[str8],row[str9])

# %%
import bs4
from bs4 import BeautifulSoup
import requests
import sqlite3

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
k = 0

for j in range(1,30):
    url = f"https://www.booking.com/searchresults.en-us.html?label=gen173nr-1FCAEoggI46AdIM1gEaJgCiAEBmAExuAEHyAEN2AEB6AEB-AECiAIBqAIDuAKwscuiBsACAdICJDdiYmZjZDY0LTc3OTktNDA5Yi1iMTdmLWJlM2NlZTRkZGY0MdgCBeACAQ&aid=304142&ss=Los+Angeles&ssne=Los+Angeles&ssne_untouched=Los+Angeles&lang=en-us&sb=1&src_elem=sb&src=searchresults&dest_id=20014181&dest_type=city&checkin=2023-12-22&checkout=2024-01-05&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset={k}"
    response = requests.get(url, headers = headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    k+=25
    for i in soup.select('.a826ba81c4'):
        try:
            #print(i)
            print(i.select('.fcab3ed991')[0].get_text())
            print(i.select('.b5cd09854e')[0].get_text())
            print(i.select('.f0d4d6a2f5')[0].get_text())
            print(i.select('.c90c0a70d3')[0].get_text())
            print(i.select('.f9afbb0024')[0].get_text())
            print(i.select('span[aria-expanded="false"][data-testid="distance"]')[0].get_text())
            print(i.select('.b4273d69aa')[0].get_text())
            print(i.select('.fbd1d3018c')[0].get_text())
            print(i.select('.df597226dd')[0].get_text())
            print('\n --------------------\n ')
        except Exception as e:
            print('')
# Out:
# Sign in, save money
#
# Central Los Angeles Hollywood apartments
# 10
# Exceptional
# 9 reviews
# Comfort 10
# 3.4 miles from center
# Los Angeles
# $4,166
# Three-Bedroom Apartment
#
#  --------------------
#
# Mr C Beverly Hills
# 7.2
# Good
# 249 reviews
#
# Downtown Los Angeles Apartment
# 8.0
# Very Good
# 1 review
#
#
# Renaissance Los Angeles Airport Hotel
# 7.8
# Good
# 1,241 reviews
# Comfort 8.5
# 10.8 miles from center
# LAX Area, Los Angeles
# $2,187
# Guest Room, 1 King
#
#  --------------------
#
# Hollywood House With Large Yard
#
# Las Palmas: STYLISH! Coastal-chic condo with 2 Master Suites in Santa Monica
#
# Lovely Single Apartment #5
# 7.0
# Good
# 1 review
#
# Hollywood Homes minutes to everything SPACIOUS AND FREE PARKING
# 8.7
# Excellent
# 319 reviews
# Comfort 9.0
# 4.7 miles from center
# Hollywood, Los Angeles
# $6,128
# Studio
#
#  --------------------
#
# Lovely apartment in West Hollywood
#
# citizenM Los Angeles Downtown
# 8.8
# Excellent
# ...

# %%
c.executemany('INSERT INTO Hotel (Name, Rating, Performances, Reviews, Comfort, Distances, Location, Price, Discription) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)',
                          i.find_all('.fcab3ed991')[0].get_text(),
                          i.select('.b5cd09854e')[0].get_text(),
                          i.select('.f0d4d6a2f5')[0].get_text(),
                          i.select('.c90c0a70d3')[0].get_text(),
                          i.select('.f9afbb0024')[0].get_text(),
                          i.select('span[aria-expanded="false"][data-testid="distance"]')[0].get_text(),
                          i.select('.b4273d69aa')[0].get_text(),
                          i.select('.fbd1d3018c')[0].get_text(),
                          i.select('.df597226dd')[0].get_text())
